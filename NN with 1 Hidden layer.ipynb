# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# read the dataset
concrete_data = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv')
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
#Part A questions


concrete_data_columns = concrete_data.columns
X = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']]  # Replace 'target_column_name' with the name of your target column
y = concrete_data['Strength']

X.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
n_cols = X.shape[1]
#Neural network model
def neural_network():
    model = Sequential()
    model.add(Dense(5, activation ='relu', input_shape = (n_cols,)))
    model.add(Dense(10, activation ='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam',loss= 'mean_squared_error' )
    return model

# %%
num_iterations = 50
result_list = []

for _ in  range(num_iterations):
    X_train,  X_test, y_train, y_test = train_test_split( X_norm, y, test_size=0.3)
    model = neural_network()
    model.fit(X, y, validation_split=0.3, epochs=50, verbose=2)
    score = model.evaluate(X_test, y_test, verbose = 0) 
    prediction = model.predict(X_test) 
    mse= mean_squared_error(y_test, prediction)  
    result_list.append(mse)
# Out:
# Train on 721 samples, validate on 309 samples
# Epoch 1/50
#  - 2s - loss: 2071.3916 - val_loss: 1196.5215
# Epoch 2/50
#  - 0s - loss: 1159.9144 - val_loss: 748.1786
# Epoch 3/50
#  - 0s - loss: 973.4499 - val_loss: 694.6737
# Epoch 4/50
#  - 0s - loss: 863.7925 - val_loss: 580.2912
# Epoch 5/50
#  - 0s - loss: 772.3490 - val_loss: 512.1355
# Epoch 6/50
#  - 0s - loss: 694.2159 - val_loss: 450.8033
# Epoch 7/50
#  - 0s - loss: 624.5411 - val_loss: 391.0117
# Epoch 8/50
#  - 0s - loss: 565.0727 - val_loss: 367.9661
# Epoch 9/50
#  - 0s - loss: 519.7440 - val_loss: 347.6038
# Epoch 10/50
#  - 0s - loss: 481.2317 - val_loss: 281.1251
# Epoch 11/50
#  - 0s - loss: 440.3264 - val_loss: 260.4190
# Epoch 12/50
#  - 0s - loss: 412.0347 - val_loss: 239.9876
# Epoch 13/50
#  - 0s - loss: 388.4404 - val_loss: 236.1799
# Epoch 14/50
#  - 0s - loss: 363.8145 - val_loss: 235.6407
# Epoch 15/50
#  - 0s - loss: 344.1617 - val_loss: 185.4625
# Epoch 16/50
# ...

# %%
result_list
# Out:
# [1604.858536597116,
#  1670.167349109678,
#  1516.3257713593507,
#  1539.4411973570166,
#  1571.9196185332178,
#  1603.4446653687685,
#  1669.499820544612,
#  1541.6167000975304,
#  1537.7994856962698,
#  1558.1981385268878,
#  1611.9102458717043,
#  1566.31287610792,
#  1676.0117802672676,
#  1613.756591034042,
#  1574.5196632132036,
#  1522.3370026226241,
#  1485.853178008831,
#  1567.4430676479078,
#  1506.7309448049234,
#  1527.7518358321927,
#  1564.9820725860852,
#  1563.9797447313856,
#  1390.141856004659,
#  1621.754374800911,
#  1494.8454116495166,
#  1542.5711203187839,
#  1428.976273011105,
#  1526.8508956945786,
#  1457.1131581368575,
#  1655.3279554777787,
#  1479.8266822859598,
#  1514.3377343751056,
#  1589.1813376224536,
#  1470.7912976304558,
#  1573.4136891765015,
#  1593.6747970568365,
#  1492.5549216052905,
#  1486.573985959425,
#  1538.104996898603,
#  1473.423347601806,
#  1576.9565893457016,
#  1529.375559696436,
#  1530.7301460385302,
#  1502.3578236646333,
# ...

# %%
mean = sum(result_list)/len(result_list)
print(mean)
# Out:
# 1546.9623200272408

# %%
variance = sum([((x - mean) ** 2) for x in result_list]) / len(result_list)
res = variance ** 0.5
 
# Printing result
print("Standard deviation of sample is : " + str(res))
# Out:
# Standard deviation of sample is : 60.143877024381496
